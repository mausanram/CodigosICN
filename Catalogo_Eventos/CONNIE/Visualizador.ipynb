# %%
import pickle as pck
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
from functions_PDF import pdf_creator3x3, pdf_creator3x3_indexs, pdf_creator3x3_verticals
from functions_CONNIE import DataFrame_muons, pixel_rot

import skimage as sk
import scipy.ndimage as nd
import numpy.ma as ma

# from ROOT import TFile, TTree

## Configuración del estilo de las imágenes
plt.rcParams.update({
    "image.origin": "lower",
    "image.aspect": 1,
    #"text.usetex": True,
    "grid.alpha": .5,
    "axes.linewidth":2,
    "lines.linewidth" : 1,
    "font.size":    15.0,
    "xaxis.labellocation": 'right',  # alignment of the xaxis label: {left, right, center}
    "yaxis.labellocation": 'top',  # alignment of the yaxis label: {bottom, top, center}
    "xtick.top":           True ,  # draw ticks on the top side
    "xtick.major.size":    8    ,# major tick size in points
    "xtick.minor.size":    4      ,# minor tick size in points
    "xtick.direction":     'in',
    "xtick.minor.visible": True,
    "ytick.right":           True ,  # draw ticks on the top side
    "ytick.major.size":    8    ,# major tick size in points
    "ytick.minor.size":    4      ,# minor tick size in points
    "ytick.direction":     'in',
    "ytick.minor.visible": True,
    "ytick.major.width":   2   , # major tick width in points
    "ytick.minor.width":   1 ,
    "xtick.major.width":   2   , # major tick width in points
    "xtick.minor.width":   1 ,
    "legend.framealpha": 0 ,
    "legend.loc": 'best',
})

colorbar='jet'
Norm = matplotlib.colors.LogNorm(vmin=10**-1, vmax=10 * 10**0)

# %%
######## Nueva definición de la elipcidad ############
# path = './Diccionarios_Espetro_Muones/dict_muons_NSAMP324_Extensions_1_2_4_NIMGS_393_SOL_0.65_ELIP_0.65_NSIGMAS_13_dEDL_0_SIZE_250x539_KeV_.pkl'
# path = './Diccionarios_Espetro_Muones/dict_muons_NSAMP324_Extensions_1_2_4_NIMGS_393_SOL_0.65_ELIP_0.65_NSIGMAS_13_DEDL_0_SIZE_250x539_KeV_n.pkl'
# path = './Diccionarios_Espetro_Muones/dict_muons_NSAMP324_Extensions_1_2_4_NIMGS_393_SOL_0.65_ELIP_0.65_NSIGMAS_13_DEDL_1100_SIZE_250x539_KeV_n.pkl'
# path = './dict_muons_NSAMP400_CONNIE_RUNID_116_Images_684_img1_Sol_0.65_Elip_0.65_SIZE_1022x420__electrons_new.pkl'

path = './dict_muons_NSAMP400_CONNIE_RUNID_116_NIMG_684_SOL_0.65_ELIP_0.65_DEDL_1300_SIZE_1022x420_KeV_new.pkl'



histogram = open(path, 'rb')
data_histogram = pck.load(histogram)
histogram.close()

#### Visualizar las keys del diccionario ####
print('Las unidades de los datos están en: ', data_histogram['Energy_Units'])
print('Llaves principales del diccionario: ', data_histogram.keys())
print('Llaves secuandarias por extensión: ', data_histogram['extension_1'].keys(), end='\n\n')
# print(type(data_histogram['extension_1']['all_events']))
# data_muons_extension_1 = data_histogram['extension_1']
# data_muons_extension_2 = data_histogram['extension_2']
# data_muons_extension_4 = data_histogram['extension_4']
Ext = 1

n_muons = data_histogram['All_Muons_Detected']
print('Se detectaron ', n_muons, ' muones. ')
DF_muons, list_datamask = DataFrame_muons(data_histogram, extension=Ext)
# Out:
# Las unidades de los datos están en:  2
# Llaves principales del diccionario:  dict_keys(['Num_Images', 'All_Muons_Detected', 'Energy_Units', 'Elipcidad', 'Solidity', 'extension_1'])
# Llaves secuandarias por extensión:  dict_keys(['charge', 'deltaEL', 'deltaL', 'all_events', 'theta', 'phi', 'elip', 'sol', 'all_events_elip', 'all_events_sol', 'datamasked'])
#
# Se detectaron  8539  muones.

# %%
import matplotlib.colors


n_label = 1009

fig, axs = plt.subplots(ncols=1, nrows=1, figsize=[7,7])
x1 = axs.imshow(list_datamask[n_label], cmap=colorbar, norm=Norm)
fig.colorbar(x1, ax=axs)

display(DF_muons.iloc[[n_label]])
print('Shape (Y, X): ', list_datamask[n_label].shape)
plt.show()
# Out:
#          Solidity  Elipticity  Theta (Deg)  Phi (Deg)  Charge (KeV)    l (cm)  \
# Muon ID
# 1009     0.681745    0.924231    60.134651   0.256553      1.425765  0.145593
#
#          dEdL (KeV/cm)
# Muon ID
# 1009          9.792811
# Shape (Y, X):  (10, 85)

# %%
### Se crea el dataframe y se selecciona un rango de datos ###
Ext = 1
DF_muons, list_datamask = DataFrame_muons(data_histogram, extension=Ext)

list_newmatrix = []
list_indexs =[]
range_in_phi = DF_muons[DF_muons['Phi (Deg)'].between(175, 185)]
# range_in_phi = DF_muons[DF_muons['Phi (Deg)'].between(0, 90)]

for index in range_in_phi.index:
    # print(index)
    list_newmatrix.append(list_datamask[index])
    list_indexs.append(index)

print("Muons Detected: ", len(list_indexs))
print("Muons in the range: ", list_indexs)

plt.imshow(list_newmatrix[4], norm=Norm, cmap=colorbar)
plt.show()
# Out:
# Muons Detected:  205
# Muons in the range:  [2, 4, 31, 33, 68, 103, 124, 142, 264, 276, 289, 293, 325, 335, 349, 370, 379, 404, 409, 438, 463, 538, 574, 584, 596, 630, 642, 650, 654, 670, 697, 780, 802, 811, 889, 931, 941, 953, 973, 1005, 1019, 1049, 1081, 1090, 1101, 1124, 1161, 1181, 1186, 1218, 1237, 1300, 1361, 1416, 1476, 1491, 1560, 1649, 1673, 1683, 1731, 1735, 1780, 1798, 1822, 1837, 1877, 1901, 1920, 1933, 1934, 1970, 2009, 2019, 2032, 2044, 2045, 2067, 2072, 2073, 2111, 2138, 2162, 2175, 2176, 2222, 2229, 2264, 2270, 2280, 2282, 2317, 2330, 2335, 2339, 2375, 2453, 2454, 2478, 2479, 2480, 2523, 2524, 2528, 2550, 2571, 2624, 2660, 2702, 2716, 2750, 2754, 2769, 2790, 2837, 2892, 2899, 2937, 2988, 3034, 3067, 3075, 3102, 3198, 3215, 3218, 3288, 3321, 3335, 3440, 3452, 3467, 3474, 3520, 3539, 3553, 3561, 3619, 3621, 3651, 3652, 3654, 3659, 3739, 3810, 3834, 3967, 4010, 4033, 4045, 4151, 4223, 4368, 4442, 4490, 4678, 4778, 4828, 4849, 4992, 5000, 5005, 5039, 5059, 5151, 5248, 5283, 5542, 5575, 5645, 5674, 5679, 5839, 5902, 5997, 6002, 6074, 6158, 6242, 6256, 6382, 6397, 6458, 6596, 7033, 7042, 7150, 7226, 7273, 7404, 7748, 7758, 7853, 7897, 7907, 7954, 8046, 8183, 8190, 8214, 8230, 8443, 8457, 8516, 8532]

# %%
n_label = 404

fig, axs = plt.subplots(ncols=1, nrows=1, figsize=[7,7])
x1 = axs.imshow(list_datamask[n_label], cmap=colorbar, norm=Norm)
# fig.colorbar(x1, ax=axs)

display(DF_muons.iloc[[n_label]])
print('Shape (Y, X): ', list_datamask[n_label].shape)
plt.show()
# Out:
#          Solidity  Elipticity  Theta (Deg)   Phi (Deg)  Charge (KeV)  \
# Muon ID
# 404      0.782051    0.895289     51.19702  178.386624      1.131423
#
#            l (cm)  dEdL (KeV/cm)
# Muon ID
# 404      0.115696       9.779307
# Shape (Y, X):  (8, 61)

# %%
list_phi_ext1 = data_histogram['extension_1']['phi']
list_mask_rot = []

list_listsnxny = []

for index in list_indexs[:]:
    datamask = list_datamask[index]
    ylen, xlen = datamask.shape
    list_nxny = []

    data_mask_zeros = np.empty((ylen + 150, xlen+50))
    data_mask_zeros[:] = 0
    ylen_zeros, xlen_zeros = data_mask_zeros.shape
    # print(data_mask_zeros.shape)
    
    ### Angle rot ##
    phi_rot = np.pi/2 - list_phi_ext1[index]
    # print(phi_rot, phi_rot + list_phi_ext1[index])

    # print('shape original: ', xlen, ylen)
    # print('shape zeros: ', xlen_zeros, ylen_zeros)

    for y_bin in range(0, ylen):
        for x_bin in range(0, xlen):
            if datamask[y_bin][x_bin] != 0:
                nx, ny = pixel_rot(x_bin=x_bin, x0=0, y_bin=y_bin, y0=0, theta= phi_rot)
                list_nxny.append((nx + 10, ny))
                # print(nx, ny)
                data_mask_zeros[ny][nx+10] = datamask[y_bin][x_bin]

    list_listsnxny.append(list_nxny)
    label_img, nlabels_img = sk.measure.label(data_mask_zeros > 0, connectivity=2, return_num=True)
    loc = nd.find_objects(label_img == 1)[0]
    mask_rot = np.invert(label_img==1)
    data_mask_rot = ma.masked_array(data_mask_zeros, mask_rot)
    # data_mask_rot = ma.masked_array(data_mask_zeros[loc[0].start:loc[0].stop, loc[1].start:loc[1].stop], mask_rot[loc[0].start:loc[0].stop, loc[1].start:loc[1].stop])

    list_mask_rot.append(data_mask_rot)
    # print('Shape rot: ', data_mask_rot.shape[1], data_mask_rot.shape[0])
    
    # plt.imshow(data_mask_rot)
    # plt.show()
#

# %%
# display(list_listsnxny[1]
dict_reps = {}
for duple in list_listsnxny[1]:
    dict_reps[duple] = dict_reps.get(duple, 0) + 1

# display(dict_reps)
n_valuesrep = 0
for value in dict_reps:
    if dict_reps[value]>1:
        n_valuesrep += 1
        print(value, ': ', dict_reps[value])

print('Elements with more reps: ', n_valuesrep)
# Out:
# (10, 0) :  3
# (10, 1) :  2
# (12, 2) :  2
# (10, 3) :  2
# (14, 5) :  2
# (10, 4) :  2
# (10, 5) :  3
# (10, 6) :  2
# (11, 7) :  2
# (10, 7) :  2
# (12, 8) :  2
# (10, 8) :  2
# (13, 10) :  2
# (10, 9) :  2
# (14, 11) :  2
# (10, 10) :  2
# (10, 11) :  2
# (10, 12) :  3
# (10, 14) :  2
# (12, 15) :  2
# (10, 15) :  2
# (10, 16) :  2
# (10, 17) :  2
# (10, 18) :  2
# (10, 19) :  2
# (11, 20) :  2
# (10, 20) :  2
# (10, 21) :  3
# (13, 23) :  2
# (10, 22) :  2
# (10, 23) :  2
# (11, 24) :  2
# (10, 25) :  3
# (10, 26) :  2
# (10, 27) :  2
# (12, 28) :  2
# (10, 28) :  2
# (11, 29) :  2
# (10, 30) :  2
# (10, 31) :  2
# (9, 31) :  2
# (10, 32) :  2
# (11, 33) :  2
# (10, 33) :  2
# (10, 34) :  2
# (13, 36) :  2
# (10, 35) :  2
# (9, 36) :  2
# (10, 36) :  2
# (10, 38) :  3
# (10, 39) :  2
# (11, 40) :  2
# (12, 41) :  2
# (10, 41) :  2
# (8, 41) :  2
# (13, 43) :  2
# (14, 44) :  2
# (9, 42) :  2
# (10, 43) :  2
# (10, 44) :  3
# (11, 46) :  2
# (10, 46) :  2
# (10, 47) :  2
# (10, 48) :  2
# Elements with more reps:  64

# %%
PDF_rot_name = 'Muons_PHI_BETWEEN_0-90_EXT1_DEDL_1300_rot.pdf'
pdf_creator3x3_verticals(pdf_name=PDF_rot_name, list_pixelmatrix=list_mask_rot)
# Out:
# The PDF is being created
# 2380  muons will be display
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_32153/2205970120.py in <module>
#       1 PDF_rot_name = 'Muons_PHI_BETWEEN_0-90_EXT1_DEDL_1300_rot.pdf'
# ----> 2 pdf_creator3x3_verticals(pdf_name=PDF_rot_name, list_pixelmatrix=list_mask_rot)
#
# ~/Documents/MauSan/Programas/Repositorio_Git/Catalogo_Eventos/CONNIE/functions_PDF.py in pdf_creator3x3_verticals(pdf_name, list_pixelmatrix)
#     322                     axs[coord3x3[n_events - 1][0],coord3x3[n_events - 1][1]].imshow(list_pixelmatrix[index], cmap = color_map, norm = Norm)
#     323                     axs[coord3x3[n_events - 1][0],coord3x3[n_events - 1][1]].set_title('ID: ' + str(index))
# --> 324                     plt.tight_layout()
#     325
#     326                     if n_events == 9:
#
# ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    2347 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2348 def tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None):
# -> 2349     return gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2350
#    2351
#
# ~/.local/lib/python3.10/site-packages/matplotlib/figure.py in tight_layout(self, pad, h_pad, w_pad, rect)
#    3507             previous_engine = self.get_layout_engine()
#    3508             self.set_layout_engine(engine)
# -> 3509             engine.execute(self)
#    3510             if not isinstance(previous_engine, TightLayoutEngine) \
#    3511                     and previous_engine is not None:
#
# ~/.local/lib/python3.10/site-packages/matplotlib/layout_engine.py in execute(self, fig)
#     176         renderer = fig._get_renderer()
#     177         with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 178             kwargs = get_tight_layout_figure(
#     179                 fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     180                 pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#
# ~/.local/lib/python3.10/site-packages/matplotlib/_tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     264             slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
#     265
# --> 266     kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                       shape=(max_nrows, max_ncols),
#     268                                       span_pairs=span_pairs,
#
# ~/.local/lib/python3.10/site-packages/matplotlib/_tight_layout.py in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80         for ax in subplots:
#      81             if ax.get_visible():
# ---> 82                 bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      83
#      84         tight_bbox_raw = Bbox.union(bb)
#
# ~/.local/lib/python3.10/site-packages/matplotlib/artist.py in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1413     """
#    1414     try:
# -> 1415         return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1416     except TypeError:
#    1417         return obj.get_tightbbox(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4406
#    4407         for a in bbox_artists:
# -> 4408             bbox = a.get_tightbbox(renderer)
#    4409             if (bbox is not None
#    4410                     and 0 < bbox.width < np.inf
#
# ~/.local/lib/python3.10/site-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     365             The enclosing bounding box (in figure pixel coordinates).
#     366         """
# --> 367         bbox = self.get_window_extent(renderer)
#     368         if self.get_clip_on():
#     369             clip_box = self.get_clip_box()
#
# ~/.local/lib/python3.10/site-packages/matplotlib/spines.py in get_window_extent(self, renderer)
#     156             return bb
#     157         bboxes = [bb]
# --> 158         drawn_ticks = self.axis._update_ticks()
#     159
#     160         major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#
# ~/.local/lib/python3.10/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1268             tick.set_label1(label)
#    1269             tick.set_label2(label)
# -> 1270         minor_locs = self.get_minorticklocs()
#    1271         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1272         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# ~/.local/lib/python3.10/site-packages/matplotlib/axis.py in get_minorticklocs(self)
#    1489         minor_locs = np.asarray(self.minor.locator())
#    1490         if self.remove_overlapping_locs:
# -> 1491             major_locs = self.major.locator()
#    1492             transform = self._scale.get_transform()
#    1493             tr_minor_locs = transform.transform(minor_locs)
#
# ~/.local/lib/python3.10/site-packages/matplotlib/ticker.py in __call__(self)
#    2134     def __call__(self):
#    2135         vmin, vmax = self.axis.get_view_interval()
# -> 2136         return self.tick_values(vmin, vmax)
#    2137
#    2138     def tick_values(self, vmin, vmax):
#
# ~/.local/lib/python3.10/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2142         vmin, vmax = mtransforms.nonsingular(
#    2143             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2144         locs = self._raw_ticks(vmin, vmax)
#    2145
#    2146         prune = self._prune
#
# ~/.local/lib/python3.10/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2127             ticks = np.arange(low, high + 1) * step + best_vmin
#    2128             # Count only the ticks that will be displayed.
# -> 2129             nticks = ((ticks <= _vmax) & (ticks >= _vmin)).sum()
#    2130             if nticks >= self._min_n_ticks:
#    2131                 break
#
# ~/.local/lib/python3.10/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      46
# ---> 47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
#      49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %% [markdown]
# # Creación de PDF para todos los muones de una extensión

# %%
n_label = 100

fig, axs = plt.subplots(ncols=3, nrows=3, figsize=[7,7])
axs[0,0].imshow(list_datamask[n_label], cmap=colorbar)
axs[0,0].set_title('ID: ' + str(n_label))

axs[0,1].imshow(list_datamask[n_label+1], cmap=colorbar)
axs[0,1].set_title('ID: ' + str(n_label+1))

axs[0,2].imshow(list_datamask[n_label+2], cmap=colorbar)
axs[0,2].set_title('ID: ' + str(n_label+2))

axs[1,0].imshow(list_datamask[n_label+3], cmap=colorbar)
axs[1,0].set_title('ID: ' + str(n_label+3))

axs[1,1].imshow(list_datamask[n_label+4], cmap=colorbar)
axs[1,1].set_title('ID: ' + str(n_label+4))

axs[1,2].imshow(list_datamask[n_label+5], cmap=colorbar)
axs[1,2].set_title('ID: ' + str(n_label+5))

axs[2,0].imshow(list_datamask[n_label+6], cmap=colorbar)
axs[2,0].set_title('ID: ' + str(n_label+6))

axs[2,1].imshow(list_datamask[n_label], cmap=colorbar)
axs[2,1].set_title('ID: ' + str(n_label+7))

axs[2,2].imshow(list_datamask[n_label+8], cmap=colorbar)
axs[2,2].set_title('ID: ' + str(n_label+8))

plt.tight_layout()
plt.show()

# %%
Ext = 1  # Only change this value and the PDF_name

DF_muons, list_datamask = DataFrame_muons(data_histogram, extension=Ext)

# list_datamask = list_datamask[:50]
print('Len: ', len(list_datamask))
### Creación del PDF con el nombre ##
PDF_name = 'Prueba1.pdf'
c = canvas.Canvas(PDF_name, letter)
w, h = A4 ## dimensiones del formato

### Imagen provicional ###
path_image = 'Perfil_Muon.jpg'
color_matrix = [0.4, 0.4470, 0.2410]
coord3x3 = [[0,0],[0,1], [0,2], [1,0], [1,1], [1,2], [2,0], [2,1], [2,2]]
n_last_events = 0

# for extension in (1,2,4):
# c.drawString(50, h - 50, 'Extensión ' + str(Ext)) 
n_muonstot = len(list_datamask)
n_last_events = 0
n_events = 0


fig, axs = plt.subplots(ncols= 3, nrows= 3, figsize = [6,6], facecolor = color_matrix) ## Las hojas tendrán 9 muones
num_pages = 0
# c.showPage()

if (n_muonstot%9) == 0:
    # print('Hola')
    for index in range(0, len(list_datamask)):
        n_muonstot = n_muonstot - 1
        n_events = n_events + 1
        if n_events < 10: 
            # print('n_events: ', n_events)
            axs[coord3x3[n_events - 1][0],coord3x3[n_events - 1][1]].imshow(list_datamask[index], cmap = colorbar)
            axs[coord3x3[n_events - 1][0],coord3x3[n_events - 1][1]].set_title('ID: ' + str(index))

            if n_events == 9:
                n_events = 10
        
        if n_events == 10:
            n_events = 0
            num_pages = num_pages + 1
            fig.savefig(path_image)
            img = ImageReader(path_image)

            # Obtener el ancho y alto de la imagen.
            img_w, img_h = img.getSize()

            # h - img_h es el alto de la hoja menos el alto de la imagen.
            c.drawImage(img, w - img_w + 10, h - img_h - 90)
            c.drawString(w/2, 40, str(num_pages))
            c.showPage()
            # plt.imshow(event)
            # plt.show()
            plt.close()
            ! rm Perfil_Muon.jpg

            fig, axs = plt.subplots(ncols= 3, nrows= 3, figsize = [6,6], facecolor = color_matrix)

elif (n_muonstot%9) != 0:
    # print('No Hola')
    Resto = n_muonstot%9

    for index in range(0, len(list_datamask)):
        n_muonstot = n_muonstot - 1
        n_events = n_events + 1

        if n_muonstot >= Resto:
            print('Primera condicion')
            if n_events < 10: 
                # print('n_events: ', n_events)
                axs[coord3x3[n_events - 1][0],coord3x3[n_events - 1][1]].imshow(list_datamask[index], cmap = colorbar)
                axs[coord3x3[n_events - 1][0],coord3x3[n_events - 1][1]].set_title('ID: ' + str(index))

                if n_events == 9:
                    n_events = 10

            if n_events == 10:
                print('Estoy aqui')
                n_events = 0
                num_pages = num_pages + 1
                fig.savefig(path_image)
                img = ImageReader(path_image)

                # Obtener el ancho y alto de la imagen.
                img_w, img_h = img.getSize()
                print('Aqui ', img_w)

                # h - img_h es el alto de la hoja menos el alto de la imagen.
                c.drawImage(img, w - img_w+10, h - img_h-90)
                c.drawString(w/2, 40, str(num_pages))
                c.showPage()
                # plt.imshow(event)
                # plt.show()
                plt.close()
                ! rm Perfil_Muon.jpg

                fig, axs = plt.subplots(ncols= 3, nrows= 3, figsize = [6,6], facecolor = color_matrix)

        elif n_muonstot<Resto:
            print('Segunda condicion')
            n_last_events = n_last_events + 1

            axs[coord3x3[n_last_events - 1][0],coord3x3[n_last_events - 1][1]].imshow(list_datamask[index], cmap=colorbar)
            axs[coord3x3[n_last_events - 1][0],coord3x3[n_last_events - 1][1]].set_title('ID: ' + str(index))

            if n_muonstot == 0:
                # plt.show()
                num_pages = num_pages + 1
                fig.savefig(path_image)
                img = ImageReader(path_image)

                # Obtener el ancho y alto de la imagen.
                img_w, img_h = img.getSize()

                # h - img_h es el alto de la hoja menos el alto de la imagen.
                c.drawImage(img, w - img_w + 50, h - img_h - 60)
                c.drawString(w/2, 40, str(num_pages))
                c.showPage()
                # plt.imshow(event)
                # plt.show()
                plt.close()
                ! rm Perfil_Muon.jpg

                fig, axs = plt.subplots(ncols= 3, nrows= 3, figsize = [10,10], facecolor = color_matrix)
        
plt.close()
c.save()
# Out:
# Len:  1361
# No Hola
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Primera condicion
# Estoy aqui
# Aqui  600
# Segunda condicion
# Segunda condicion

# %% [markdown]
# # Creción de PDFs para un rango de datos

# %%
Ext = 1
DF_muons, list_datamask = DataFrame_muons(data_histogram, extension=Ext)

list_newmatrix = []
list_indexs =[]
# range_in_phi = DF_muons[DF_muons['Phi (Deg)'].between(165, 195)]
range_in_phi = DF_muons[DF_muons['Phi (Deg)'].between(85, 90)]

for index in range_in_phi.index:
    # print(index)
    list_newmatrix.append(list_datamask[index])
    list_indexs.append(index)

print('Muones en el rango deseado: ', len(list_indexs))

# plt.imshow(list_newmatrix[0])
# PDF_name = 'Muons_PHI_BETWEEN_0-90_EXT1_DEDL_1300.pdf'
# PDF_name = 'Muons_PHI_BETWEEN_90-180_EXT1_DEDL_1400.pdf'
PDF_name = 'Muons_PHI_BETWEEN_85-95_EXT1_DEDL_1300.pdf'
pdf_creator3x3_indexs(PDF_name, list_newmatrix[:300], list_indexs[:300], norm=Norm)
# Out:
# Muones en el rango deseado:  171
# The PDF is being created
# 171  muons will be display
# Done
# 0
